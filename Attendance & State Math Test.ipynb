# %% [markdown]
# ## Is there a relationship between attendance and NY State Math Test?

# %%
import pandas as pd
import datetime

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
att = pd.read_csv('admissions_2013-2022', index_col = 0)

# %%
math_results = "https://raw.githubusercontent.com/aalilyah/DS4a/main/Math_Results_2015-2022.csv"
results = pd.read_csv(math_results, index_col = 0)

# %%
att.Year= att.Year.astype(str)
att_clean_year = []

for x in att.Year:
    list1 = x[5:8]
    att_clean_year.append(list1)
    
att.Year = att_clean_year

# %%
results = results[results.index.str.contains('02M') | results.index.str.contains('24Q')  | 
                results.index.str.contains('31R') | results.index.str.contains('20K')  | 
                results.index.str.contains('10X')]
results = results[(results['Grade']== '6') |(results['Grade']== '7') |(results['Grade']== '8')]

# %%
results.reset_index(inplace = True)

# %%
results
# Out:
#      School_DBN                               School_Name Grade  Year  \
# 0        02M104                   J.H.S. 104 SIMON BARUCH     6  2015
# 1        02M104                   J.H.S. 104 SIMON BARUCH     6  2016
# 2        02M104                   J.H.S. 104 SIMON BARUCH     6  2017
# 3        02M104                   J.H.S. 104 SIMON BARUCH     6  2018
# 4        02M104                   J.H.S. 104 SIMON BARUCH     6  2019
# ...         ...                                       ...   ...   ...
# 1601     31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8  2016
# 1602     31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8  2017
# 1603     31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8  2018
# 1604     31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8  2019
# 1605     31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8  2022
#
#           Category  Number_Tested Mean_Scale_Score Number_Level_1  \
# 0     All Students            376              326             53
# 1     All Students            358              329             32
# 2     All Students            358              328             36
# 3     All Students            362              607             52
# 4     All Students            354              613             28
# ...            ...            ...              ...            ...
# 1601  All Students             98              313             17
# 1602  All Students             95              306             25
# 1603  All Students             96              604             29
# 1604  All Students             89              607             20
# 1605  All Students             79              603             28
#
#      Percentage_Level_1 Number_Level_2 Percentage_Level_2 Number_Level_3  \
# 0                  14.1             82               21.8             81
# 1                   8.9             83               23.2             91
# 2                  10.1             78               21.8             97
# 3                  14.4             89               24.6            108
# 4                   7.9             51               14.4             99
# ...                 ...            ...                ...            ...
# 1601               17.3             42               42.9             28
# 1602               26.3             36               37.9             24
# 1603               30.2             30               31.3             25
# 1604               22.5             32                 36             20
# 1605               35.4             25               31.6             12
#
#      Percentage_Level_3 Number_Level_4 Percentage_Level_4 Number_Level_3+4  \
# 0                  21.5            160               42.6              241
# 1                  25.4            152               42.5              243
# 2                  27.1            147               41.1              244
# 3                  29.8            113               31.2              221
# 4                    28            176               49.7              275
# ...                 ...            ...                ...              ...
# 1601               28.6             11               11.2               39
# 1602               25.3             10               10.5               34
# 1603                 26             12               12.5               37
# 1604               22.5             17               19.1               37
# 1605               15.2             14               17.7               26
#
#      Percentage_Level_3+4
# 0                    64.1
# 1                    67.9
# 2                    68.2
# 3                      61
# 4                    77.7
# ...                   ...
# 1601                 39.8
# 1602                 35.8
# 1603                 38.5
# 1604                 41.6
# 1605                 32.9
#
# [1606 rows x 17 columns]

# %%
results.Year= results.Year.astype(str)
results_clean_year = []

for x in results.Year:
    list1 = x[2:4]
    results_clean_year.append(list1)
    
results.Year = results_clean_year

# %%
#math test clean
results.rename(columns = {'School_DBN': 'DBN'}, inplace = True)

# %%
results
# Out:
#          DBN                               School_Name Grade Year  \
# 0     02M104                   J.H.S. 104 SIMON BARUCH     6   15
# 1     02M104                   J.H.S. 104 SIMON BARUCH     6   16
# 2     02M104                   J.H.S. 104 SIMON BARUCH     6   17
# 3     02M104                   J.H.S. 104 SIMON BARUCH     6   18
# 4     02M104                   J.H.S. 104 SIMON BARUCH     6   19
# ...      ...                                       ...   ...  ...
# 1601  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   16
# 1602  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   17
# 1603  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   18
# 1604  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   19
# 1605  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   22
#
#           Category  Number_Tested Mean_Scale_Score Number_Level_1  \
# 0     All Students            376              326             53
# 1     All Students            358              329             32
# 2     All Students            358              328             36
# 3     All Students            362              607             52
# 4     All Students            354              613             28
# ...            ...            ...              ...            ...
# 1601  All Students             98              313             17
# 1602  All Students             95              306             25
# 1603  All Students             96              604             29
# 1604  All Students             89              607             20
# 1605  All Students             79              603             28
#
#      Percentage_Level_1 Number_Level_2 Percentage_Level_2 Number_Level_3  \
# 0                  14.1             82               21.8             81
# 1                   8.9             83               23.2             91
# 2                  10.1             78               21.8             97
# 3                  14.4             89               24.6            108
# 4                   7.9             51               14.4             99
# ...                 ...            ...                ...            ...
# 1601               17.3             42               42.9             28
# 1602               26.3             36               37.9             24
# 1603               30.2             30               31.3             25
# 1604               22.5             32                 36             20
# 1605               35.4             25               31.6             12
#
#      Percentage_Level_3 Number_Level_4 Percentage_Level_4 Number_Level_3+4  \
# 0                  21.5            160               42.6              241
# 1                  25.4            152               42.5              243
# 2                  27.1            147               41.1              244
# 3                  29.8            113               31.2              221
# 4                    28            176               49.7              275
# ...                 ...            ...                ...              ...
# 1601               28.6             11               11.2               39
# 1602               25.3             10               10.5               34
# 1603                 26             12               12.5               37
# 1604               22.5             17               19.1               37
# 1605               15.2             14               17.7               26
#
#      Percentage_Level_3+4
# 0                    64.1
# 1                    67.9
# 2                    68.2
# 3                      61
# 4                    77.7
# ...                   ...
# 1601                 39.8
# 1602                 35.8
# 1603                 38.5
# 1604                 41.6
# 1605                 32.9
#
# [1606 rows x 17 columns]

# %%
#columns to str to then merge

#att.DBN = att.DBN.astype(str)
#results.DBN = results.DBN.astype(str)

#att.Year = att.Year.astype(str)
#results.Year = results.Year.astype(str)

#att.Grade = att.Grade.astype(str)
#results.Grade = results.Grade.astype(str)

# %%
test= results.merge(att, how = 'left', on = ['DBN', 'Year'])

# %%
results.head()
# Out:
#       DBN              School_Name Grade Year      Category  Number_Tested  \
# 0  02M104  J.H.S. 104 SIMON BARUCH     6   15  All Students            376
# 1  02M104  J.H.S. 104 SIMON BARUCH     6   16  All Students            358
# 2  02M104  J.H.S. 104 SIMON BARUCH     6   17  All Students            358
# 3  02M104  J.H.S. 104 SIMON BARUCH     6   18  All Students            362
# 4  02M104  J.H.S. 104 SIMON BARUCH     6   19  All Students            354
#
#   Mean_Scale_Score Number_Level_1 Percentage_Level_1 Number_Level_2  \
# 0              326             53               14.1             82
# 1              329             32                8.9             83
# 2              328             36               10.1             78
# 3              607             52               14.4             89
# 4              613             28                7.9             51
#
#   Percentage_Level_2 Number_Level_3 Percentage_Level_3 Number_Level_4  \
# 0               21.8             81               21.5            160
# 1               23.2             91               25.4            152
# 2               21.8             97               27.1            147
# 3               24.6            108               29.8            113
# 4               14.4             99                 28            176
#
#   Percentage_Level_4 Number_Level_3+4 Percentage_Level_3+4
# 0               42.6              241                 64.1
# 1               42.5              243                 67.9
# 2               41.1              244                 68.2
# 3               31.2              221                   61
# 4               49.7              275                 77.7

# %%
att.head()
# Out:
#       DBN Year  % Attendance
# 0  02M104   14          96.3
# 2  02M104   15          96.9
# 3  02M104   16          96.7
# 5  02M104   17          96.5
# 6  02M104   18          96.6

# %%
test.to_csv('attendace_corr_statemathtest')

# %%
test.dropna(axis = 0)
# Out:
#           DBN                               School_Name Grade Year  \
# 0      02M104                   J.H.S. 104 SIMON BARUCH     6   15
# 1      02M104                   J.H.S. 104 SIMON BARUCH     6   15
# 2      02M104                   J.H.S. 104 SIMON BARUCH     6   15
# 3      02M104                   J.H.S. 104 SIMON BARUCH     6   15
# 4      02M104                   J.H.S. 104 SIMON BARUCH     6   15
# ...       ...                                       ...   ...  ...
# 28982  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   19
# 28983  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   19
# 28984  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   19
# 28985  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   19
# 28986  31R861  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP     8   19
#
#            Category  Number_Tested Mean_Scale_Score Number_Level_1  \
# 0      All Students            376              326             53
# 1      All Students            376              326             53
# 2      All Students            376              326             53
# 3      All Students            376              326             53
# 4      All Students            376              326             53
# ...             ...            ...              ...            ...
# 28982  All Students             89              607             20
# 28983  All Students             89              607             20
# 28984  All Students             89              607             20
# 28985  All Students             89              607             20
# 28986  All Students             89              607             20
#
#       Percentage_Level_1 Number_Level_2 Percentage_Level_2 Number_Level_3  \
# 0                   14.1             82               21.8             81
# 1                   14.1             82               21.8             81
# 2                   14.1             82               21.8             81
# 3                   14.1             82               21.8             81
# 4                   14.1             82               21.8             81
# ...                  ...            ...                ...            ...
# 28982               22.5             32                 36             20
# 28983               22.5             32                 36             20
# 28984               22.5             32                 36             20
# 28985               22.5             32                 36             20
# 28986               22.5             32                 36             20
#
#       Percentage_Level_3 Number_Level_4 Percentage_Level_4 Number_Level_3+4  \
# 0                   21.5            160               42.6              241
# 1                   21.5            160               42.6              241
# 2                   21.5            160               42.6              241
# 3                   21.5            160               42.6              241
# 4                   21.5            160               42.6              241
# ...                  ...            ...                ...              ...
# 28982               22.5             17               19.1               37
# 28983               22.5             17               19.1               37
# 28984               22.5             17               19.1               37
# 28985               22.5             17               19.1               37
# 28986               22.5             17               19.1               37
#
#       Percentage_Level_3+4  % Attendance
# 0                     64.1          96.9
# 1                     64.1          96.5
# 2                     64.1          97.7
# 3                     64.1          93.2
# 4                     64.1          97.2
# ...                    ...           ...
# 28982                 41.6          93.3
# 28983                 41.6          88.3
# 28984                 41.6          92.2
# 28985                 41.6          92.4
# 28986                 41.6          91.6
#
# [28728 rows x 18 columns]

# %%
#candle cart.. high low or mean.

# %%
x is year y is district ... then break down by grade level to filter.. 

out of all the district which 

distrcit do over years. do it over all district then compare the district...

line graph to see correlation to see which district vs attendance...


what we are hoping to see as out end product... is the goal to say our data shows these last few years... 
all still do well throughout the years... 

how are each district doing throughtout the year by grade..
