# %% [markdown]
# ## Is there a relationship between attendance and NY State Math Test?

# %%
import pandas as pd
import datetime

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
attendance = "https://raw.githubusercontent.com/aalilyah/DS4a/Admissions/admissions_2013-2022"
att = pd.read_csv(attendance, index_col = 0)

math_results = "https://raw.githubusercontent.com/aalilyah/DS4a/main/Math_Results_2015-2022.csv"
results = pd.read_csv(math_results, index_col = 0)

# %%
results.index.name = 'DBN'

# %%
fix_year_results = results.copy()
fix_year_results.head()
# Out:
#                       School_Name Grade  Year      Category  Number_Tested  \
# DBN
# 01M015  P.S. 015 ROBERTO CLEMENTE     3  2016  All Students             21
# 01M015  P.S. 015 ROBERTO CLEMENTE     3  2017  All Students             29
# 01M015  P.S. 015 ROBERTO CLEMENTE     3  2018  All Students             20
# 01M015  P.S. 015 ROBERTO CLEMENTE     3  2019  All Students             26
# 01M015  P.S. 015 ROBERTO CLEMENTE     3  2022  All Students             21
#
#        Mean_Scale_Score Number_Level_1 Percentage_Level_1 Number_Level_2  \
# DBN
# 01M015              275             13               61.9              4
# 01M015              302              8               27.6              9
# 01M015              616              1                  5              0
# 01M015              606              4               15.4              4
# 01M015              583             12               57.1              4
#
# ...

# %%
results
# Out:
#                                           School_Name       Grade  Year  \
# DBN
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2016
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2017
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2018
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2019
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2022
# ...                                               ...         ...   ...
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2016
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2017
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2018
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2019
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2022
#
#             Category  Number_Tested Mean_Scale_Score Number_Level_1  \
# DBN
# ...

# %%
fix_year_results
# Out:
#                                           School_Name       Grade  Year  \
# DBN
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2016
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2017
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2018
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2019
# 01M015                      P.S. 015 ROBERTO CLEMENTE           3  2022
# ...                                               ...         ...   ...
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2016
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2017
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2018
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2019
# 32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades  2022
#
#             Category  Number_Tested Mean_Scale_Score Number_Level_1  \
# DBN
# ...

# %%
a = fix_year_results['Year'].astype(str)
clean_year = []

for x in a:
    list1 = x[2:4]
    clean_year.append(list1)
    
fix_year_results['Year'] = clean_year

# %%
fix_year_att = att.copy()
fix_year_att.loc[fix_year_att.Grade ==8]
# Out:
#         Grade     Year % Attendance
# DBN
# 01M034    8.0  2013-14         90.6
# 01M034    8.0  2014-15         92.0
# 01M034    8.0  2015-16         91.5
# 01M034    8.0  2016-17         90.4
# 01M034    8.0  2017-18         91.2
# ...       ...      ...          ...
# 75X811    8.0  2015-16            s
# 75X811    8.0  2015-16            s
# 75X811    8.0  2016-17            s
# 75X811    8.0  2016-17            s
# 75X811    8.0  2018-19            s
#
# [41625 rows x 3 columns]

# %%
b = fix_year_att['Year'].astype(str)
att_clean_year = []

for x in b:
    list1 = x[5:8]
    att_clean_year.append(list1)
    
    
fix_year_att['Grade'] = fix_year_att['Grade'].fillna(0).astype(int)
fix_year_att.index = fix_year_att.index.astype(str)

fix_year_att['Year'] = att_clean_year

# %%
fix_year_att = fix_year_att.reset_index()
fix_year_results = fix_year_results.reset_index()

# %%
fix_year_att.DBN = fix_year_att.DBN.astype(str)
fix_year_results.DBN = fix_year_results.DBN.astype(str)

fix_year_att.Year = fix_year_att.Year.astype(str)
fix_year_results.Year = fix_year_results.Year.astype(str)

fix_year_att.Grade = fix_year_att.Grade.astype(str)
fix_year_results.Grade = fix_year_results.Grade.astype(str)

fix_year_att.rename(columns = {'% Attendance': 'Attendance'}, inplace = True)

fix_year_att = fix_year_att[(fix_year_att.Grade == '8')]
fix_year_att.Attendance = pd.to_numeric(att_results.Attendance, errors='coerce')
fix_year_att = fix_year_att.dropna(axis = 0)

# %%
fix_year_att
# Out:
#            DBN Grade Year  Attendance
# 38      01M034     8   14        90.6
# 39      01M034     8   15        92.0
# 40      01M034     8   16        91.5
# 41      01M034     8   17        90.4
# 42      01M034     8   18        91.2
# ...        ...   ...  ...         ...
# 190271  75X188     8   19        87.3
# 190306  75X352     8   15        90.9
# 190309  75X352     8   17        79.2
# 190310  75X352     8   18        88.9
# 190348  75X811     8   15        80.2
#
# [29030 rows x 4 columns]

# %%
fix_year_att.to_csv('attendance_8thgrade')

# %%
att_results = fix_year_att.merge(fix_year_results, how = 'left', on = ['DBN', 'Year', 'Grade'])

# %%
attvsresults = att_results.dropna(axis = 0)
attvsresults = attvsresults[(attvsresults.Grade == '8')]

#attvsresults['% Attendance'] = attvsresults[(attvsresults['% Attendance'] != 's')]
#attvsresults['% Attendance'] = attvsresults['% Attendance'].astype(int)
#attvsresults['Percentage_Level_1'] = attvsresults['Percentage_Level_1'] != 's'
#attvsresults['Percentage_Level_1'] = attvsresults['Percentage_Level_1'].fillna(0).astype(float)
#attvsresults['Percentage_Level_2'] = attvsresults['Percentage_Level_2'] != 's'
#attvsresults['Percentage_Level_2'] = attvsresults['Percentage_Level_2'].fillna(0).astype(float)
#attvsresults['Percentage_Level_3'] = attvsresults['Percentage_Level_3'] != 's'
#attvsresults['Percentage_Level_3'] = attvsresults['Percentage_Level_3'].fillna(0).astype(float)
#attvsresults['Percentage_Level_4'] = attvsresults['Percentage_Level_4'] != 's'
#attvsresults['Percentage_Level_4'] = attvsresults['Percentage_Level_4'].fillna(0).astype(float)
#attvsresults['Percentage_Level_3+4'] = attvsresults['Percentage_Level_3+4'] != 's'
#attvsresults['Percentage_Level_3+4'] = attvsresults['Percentage_Level_3+4'].fillna(0).astype(float)
#attvsresults['Grade'] = attvsresults['Grade'].astype(int)

# %%
attvsresults
# Out:
#           DBN Grade Year  Attendance  \
# 1      01M034     8   15        92.0
# 2      01M034     8   16        91.5
# 3      01M034     8   17        90.4
# 4      01M034     8   18        91.2
# 5      01M034     8   19        89.4
# ...       ...   ...  ...         ...
# 28773  32K562     8   16        97.1
# 28774  32K562     8   16        92.5
# 28775  32K562     8   17        97.8
# 28778  32K562     8   19        96.5
# 28779  32K562     8   19        94.5
#
#                                          School_Name      Category  \
# 1                     P.S. 034 FRANKLIN D. ROOSEVELT  All Students
# 2                     P.S. 034 FRANKLIN D. ROOSEVELT  All Students
# 3                     P.S. 034 FRANKLIN D. ROOSEVELT  All Students
# 4                     P.S. 034 FRANKLIN D. ROOSEVELT  All Students
# 5                     P.S. 034 FRANKLIN D. ROOSEVELT  All Students
# ...                                              ...           ...
# ...

# %%
attvsresults.to_csv('attendace_corr_statemathtest')

# %%
#candle cart.. high low or mean.
