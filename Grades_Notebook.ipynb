# %%
import pandas as pd
aa = "/content/Grades.csv"

# %%
import scipy.stats as stats
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import plotly.express as px
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import plotly.graph_objects as go

# %%
grade = pd.read_csv(aa)

# %%
grade['Year'] = pd.to_datetime(grade['Year'], format='%Y')

# %%
grade.head()
# Out:
#    District     DBN              School Name  Grade Group    Class       Year  \
# 0         2  02M104  J.H.S. 104 SIMON BARUCH      6   NaN  Class 1 2013-01-01
# 1         2  02M104  J.H.S. 104 SIMON BARUCH      7   NaN      NaN 2013-01-01
# 2         2  02M104  J.H.S. 104 SIMON BARUCH      8   NaN      NaN 2013-01-01
# 3         2  02M114  EAST SIDE MIDDLE SCHOOL      6   NaN  Class 1 2013-01-01
# 4         2  02M114  EAST SIDE MIDDLE SCHOOL      7   NaN      NaN 2013-01-01
#
#    Number Tested  Mean Scale Score  # Level 1  % Level 1  # Level 2  \
# 0          311.0             328.0       27.0        8.7       84.0
# 1          356.0             319.0       63.0       17.7      102.0
# 2          325.0             321.0       45.0       13.8      113.0
# 3          148.0             346.0        4.0        2.7       13.0
# 4          141.0             349.0        1.0        0.7       14.0
#
#    % Level 2  # Level 3  % Level 3  # Level 4  % Level 4  # Level 3+4  \
# ...

# %%
grade.drop(['DBN', 'School Name', 'Grade', 'Number Tested', 'Mean Scale Score', '# Level 1', '% Level 1',
       '# Level 2', '% Level 2', '# Level 3', '% Level 3', '# Level 4',
       '% Level 4', '# Level 3+4'], axis=1, inplace=True)

# %%
grades = grade.set_index('Year')

# %%
Class = grades.dropna().groupby(['Year', 'Class'])
Group = grades.dropna().groupby(['Year', 'Group'])

# %%
Class.head()
# Out:
#             District     DBN                       School Name  Grade  \
# Year
# 2016-01-01         2  02M104           J.H.S. 104 SIMON BARUCH      6
# 2016-01-01         2  02M114           EAST SIDE MIDDLE SCHOOL      6
# 2016-01-01         2  02M126        P.S. 126 JACOB AUGUST RIIS      6
# 2016-01-01         2  02M131                          M.S. 131      6
# 2016-01-01         2  02M167       J.H.S. 167 ROBERT F. WAGNER      6
# 2017-01-01         2  02M104           J.H.S. 104 SIMON BARUCH      6
# 2017-01-01         2  02M104           J.H.S. 104 SIMON BARUCH      7
# 2017-01-01         2  02M114           EAST SIDE MIDDLE SCHOOL      6
# 2017-01-01         2  02M114           EAST SIDE MIDDLE SCHOOL      7
# 2017-01-01         2  02M126        P.S. 126 JACOB AUGUST RIIS      6
# 2017-01-01         2  02M126        P.S. 126 JACOB AUGUST RIIS      7
# 2017-01-01         2  02M131                          M.S. 131      6
# ...

# %%
from statsmodels.tsa.stattools import adfuller

def check_stationarity(timeseries):
    # Perform the Augmented Dickey-Fuller test
    result = adfuller(timeseries)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# Breaking it down by Class

# %%
"""for name, group in Class:
    check_stationarity(group['% Level 3+4'])"""
# Out:
# "for name, group in Class:\n    check_stationarity(group['% Level 3+4'])"

# %%
"""for name, group in Class:
    model = ExponentialSmoothing(group['% Level 3+4']).fit()
    plt.plot(model.fittedvalues, label='Prediction')
    plt.plot(group['% Level 3+4'], label='Data')
    plt.legend(loc='best')
    plt.show()""
# Out:
#   File "<ipython-input-106-dedda46cff17>", line 6
#     plt.show()""
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %% [markdown]
# Breaking it down by Group

# %%
""" for name, group in Group:
    check_stationarity(group['% Level 3+4'])"""
# Out:
# " for name, group in Group:\n    check_stationarity(group['% Level 3+4'])"

# %%
"""for name, group in Group:
    model = ExponentialSmoothing(group['% Level 3+4']).fit()
    plt.plot(model.fittedvalues, label='Prediction')
    plt.plot(group['% Level 3+4'], label='Data')
    plt.legend(loc='best')
    plt.show() """
# Out:
# "for name, group in Group:\n    model = ExponentialSmoothing(group['% Level 3+4']).fit()\n    plt.plot(model.fittedvalues, label='Prediction')\n    plt.plot(group['% Level 3+4'], label='Data')\n    plt.legend(loc='best')\n    plt.show() "
