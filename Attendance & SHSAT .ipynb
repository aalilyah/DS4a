# %% [markdown]
# ## Is there a relationship between attendance and NY SHSAT?

# %%
import pandas as pd
import datetime

# %%
attendance = "https://raw.githubusercontent.com/aalilyah/DS4a/main/attendance_8thgrade"
att = pd.read_csv(attendance, index_col = 0)

shsat_results = "https://raw.githubusercontent.com/aalilyah/DS4a/main/2015-2021_SHSAT_Admissions_Test_Offers_By_Sending_School.csv"
shsat = pd.read_csv(shsat_results, index_col = 0)

# %%
att
# Out:
#            DBN  Grade  Year  Attendance
# 38      01M034      8    14        90.6
# 39      01M034      8    15        92.0
# 40      01M034      8    16        91.5
# 41      01M034      8    17        90.4
# 42      01M034      8    18        91.2
# ...        ...    ...   ...         ...
# 190271  75X188      8    19        87.3
# 190306  75X352      8    15        90.9
# 190309  75X352      8    17        79.2
# 190310  75X352      8    18        88.9
# 190348  75X811      8    15        80.2
#
# [29030 rows x 4 columns]

# %%
shsat
# Out:
#                  Year                          Feeder_School_Name  \
# School_DBN
# 01M034      2015-2016              P.S. 034 FRANKLIN D. ROOSEVELT
# 01M140      2015-2016                      P.S. 140 NATHAN STRAUS
# 01M184      2015-2016                        P.S. 184M SHUANG WEN
# 01M188      2015-2016                  P.S. 188 THE ISLAND SCHOOL
# 01M301      2015-2016       TECHNOLOGY, ARTS, AND SCIENCES STUDIO
# ...               ...                                         ...
# 84X703      2020-2021   BRONX PREPARATORY CHARTER SCHOOL (84X703)
# 84X704      2020-2021        KIPP ACADEMY CHARTER SCHOOL (84X704)
# 84X706      2020-2021      HARRIET TUBMAN CHARTER SCHOOL (84X706)
# 84X717      2020-2021               ICAHN CHARTER SCHOOL (84X717)
# 84X730      2020-2021  BRONX CHARTER SCHOOL FOR THE ARTS (84X730)
#
#             Students_in_HS_Admissions  Testers  Offers  Acceptance_Rate  \
# School_DBN
# 01M034                            8.0        8       3            37.50
# 01M140                           14.0       14       3            21.43
# 01M184                           39.0       39      19            48.72
# 01M188                            3.0        3       3           100.00
# 01M301                            6.0        6       3            50.00
# ...                               ...      ...     ...              ...
# 84X703                           19.0        8       3            37.50
# 84X704                           15.0        6       3            50.00
# 84X706                           64.0       15       3            20.00
# 84X717                           29.0        7       3            42.86
# 84X730                          100.0       13       3            23.08
#
#             Application_Rate
# School_DBN
# 01M034                100.00
# 01M140                100.00
# 01M184                100.00
# 01M188                100.00
# 01M301                100.00
# ...                      ...
# 84X703                 42.11
# 84X704                 40.00
# 84X706                 23.44
# 84X717                 24.14
# 84X730                 13.00
#
# [3620 rows x 7 columns]

# %%
a = shsat['Year'].astype(str)
clean_year = []

for x in a:
    list1 = x[7:9]
    clean_year.append(list1)
    
shsat['Year'] = clean_year
shsat

#admission rate
## acceptance rate to math grade..
## acceptance rate to attendance..

#district one has low count of students going in to take this test..
# Out:
#            Year                          Feeder_School_Name  \
# School_DBN
# 01M034       16              P.S. 034 FRANKLIN D. ROOSEVELT
# 01M140       16                      P.S. 140 NATHAN STRAUS
# 01M184       16                        P.S. 184M SHUANG WEN
# 01M188       16                  P.S. 188 THE ISLAND SCHOOL
# 01M301       16       TECHNOLOGY, ARTS, AND SCIENCES STUDIO
# ...         ...                                         ...
# 84X703       21   BRONX PREPARATORY CHARTER SCHOOL (84X703)
# 84X704       21        KIPP ACADEMY CHARTER SCHOOL (84X704)
# 84X706       21      HARRIET TUBMAN CHARTER SCHOOL (84X706)
# 84X717       21               ICAHN CHARTER SCHOOL (84X717)
# 84X730       21  BRONX CHARTER SCHOOL FOR THE ARTS (84X730)
#
#             Students_in_HS_Admissions  Testers  Offers  Acceptance_Rate  \
# School_DBN
# 01M034                            8.0        8       3            37.50
# 01M140                           14.0       14       3            21.43
# 01M184                           39.0       39      19            48.72
# 01M188                            3.0        3       3           100.00
# 01M301                            6.0        6       3            50.00
# ...                               ...      ...     ...              ...
# 84X703                           19.0        8       3            37.50
# 84X704                           15.0        6       3            50.00
# 84X706                           64.0       15       3            20.00
# 84X717                           29.0        7       3            42.86
# 84X730                          100.0       13       3            23.08
#
#             Application_Rate
# School_DBN
# 01M034                100.00
# 01M140                100.00
# 01M184                100.00
# 01M188                100.00
# 01M301                100.00
# ...                      ...
# 84X703                 42.11
# 84X704                 40.00
# 84X706                 23.44
# 84X717                 24.14
# 84X730                 13.00
#
# [3620 rows x 7 columns]

# %%
#att['Grade'] = att['Grade'].fillna(0).astype(int)

# %%
shsat_results = shsat.reset_index()

# %%
shsat_results.rename(columns = {'School_DBN': 'DBN'}, inplace = True)

# %%
shsat_results
# Out:
#          DBN Year                          Feeder_School_Name  \
# 0     01M034   16              P.S. 034 FRANKLIN D. ROOSEVELT
# 1     01M140   16                      P.S. 140 NATHAN STRAUS
# 2     01M184   16                        P.S. 184M SHUANG WEN
# 3     01M188   16                  P.S. 188 THE ISLAND SCHOOL
# 4     01M301   16       TECHNOLOGY, ARTS, AND SCIENCES STUDIO
# ...      ...  ...                                         ...
# 3615  84X703   21   BRONX PREPARATORY CHARTER SCHOOL (84X703)
# 3616  84X704   21        KIPP ACADEMY CHARTER SCHOOL (84X704)
# 3617  84X706   21      HARRIET TUBMAN CHARTER SCHOOL (84X706)
# 3618  84X717   21               ICAHN CHARTER SCHOOL (84X717)
# 3619  84X730   21  BRONX CHARTER SCHOOL FOR THE ARTS (84X730)
#
#       Students_in_HS_Admissions  Testers  Offers  Acceptance_Rate  \
# 0                           8.0        8       3            37.50
# 1                          14.0       14       3            21.43
# 2                          39.0       39      19            48.72
# 3                           3.0        3       3           100.00
# 4                           6.0        6       3            50.00
# ...                         ...      ...     ...              ...
# 3615                       19.0        8       3            37.50
# 3616                       15.0        6       3            50.00
# 3617                       64.0       15       3            20.00
# 3618                       29.0        7       3            42.86
# 3619                      100.0       13       3            23.08
#
#       Application_Rate
# 0               100.00
# 1               100.00
# 2               100.00
# 3               100.00
# 4               100.00
# ...                ...
# 3615             42.11
# 3616             40.00
# 3617             23.44
# 3618             24.14
# 3619             13.00
#
# [3620 rows x 8 columns]

# %%
att.DBN = att.DBN.astype(str)
shsat_results.DBN = shsat_results.DBN.astype(str)

att.Year = att.Year.astype(str)
shsat_results.Year = shsat_results.Year.astype(str)


SHSATvsATT = shsat_results.merge(att, how = 'left', on = ['DBN', 'Year'])

# %%
SHSATvsATT = sa.dropna(axis=0)

# %%
SHSATvsATT
# Out:
#           DBN Year                             Feeder_School_Name  \
# 0      01M034   16                 P.S. 034 FRANKLIN D. ROOSEVELT
# 1      01M034   16                 P.S. 034 FRANKLIN D. ROOSEVELT
# 2      01M034   16                 P.S. 034 FRANKLIN D. ROOSEVELT
# 3      01M034   16                 P.S. 034 FRANKLIN D. ROOSEVELT
# 4      01M034   16                 P.S. 034 FRANKLIN D. ROOSEVELT
# ...       ...  ...                                            ...
# 18523  32K562   19  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION
# 18524  32K562   19  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION
# 18525  32K562   19  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION
# 18526  32K562   19  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION
# 18527  32K562   19  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION
#
#        Students_in_HS_Admissions  Testers  Offers  Acceptance_Rate  \
# 0                            8.0        8       3            37.50
# 1                            8.0        8       3            37.50
# 2                            8.0        8       3            37.50
# 3                            8.0        8       3            37.50
# 4                            8.0        8       3            37.50
# ...                          ...      ...     ...              ...
# 18523                      122.0       53       3             5.66
# 18524                      122.0       53       3             5.66
# 18525                      122.0       53       3             5.66
# 18526                      122.0       53       3             5.66
# 18527                      122.0       53       3             5.66
#
#        Application_Rate  Grade  Attendance
# 0                100.00    8.0        91.5
# 1                100.00    8.0        91.8
# 2                100.00    8.0        90.8
# 3                100.00    8.0        92.7
# 4                100.00    8.0        90.9
# ...                 ...    ...         ...
# 18523             43.44    8.0        95.6
# 18524             43.44    8.0        95.3
# 18525             43.44    8.0        94.9
# 18526             43.44    8.0        96.5
# 18527             43.44    8.0        94.5
#
# [18173 rows x 10 columns]

# %%
SHSATvsATT.to_csv('attendace_corr_shsat')
