# %% [markdown]
# ## Is there a relationship between attendance and NY SHSAT?

# %%
import pandas as pd
import datetime

# %%
attendance = "https://raw.githubusercontent.com/aalilyah/DS4a/main/attendance_8thgrade"
att = pd.read_csv(attendance, index_col = 0)

shsat_results = "https://raw.githubusercontent.com/aalilyah/DS4a/main/2015-2021_SHSAT_Admissions_Test_Offers_By_Sending_School.csv"
shsat = pd.read_csv(shsat_results, index_col = 0)

# %%
att.set_index('DBN', inplace = True)

# %%
att = att[att.index.str.contains('02M') | att.index.str.contains('24Q')  | 
                att.index.str.contains('31R') | att.index.str.contains('20K')  | 
                att.index.str.contains('10X')]

# %%
att.drop(columns = {'Grade'} , inplace = True)

# %%
att.to_csv('attendance_8thgrade')

# %%
shsat
# Out:
#                  Year                          Feeder_School_Name  \
# School_DBN
# 01M034      2015-2016              P.S. 034 FRANKLIN D. ROOSEVELT
# 01M140      2015-2016                      P.S. 140 NATHAN STRAUS
# 01M184      2015-2016                        P.S. 184M SHUANG WEN
# 01M188      2015-2016                  P.S. 188 THE ISLAND SCHOOL
# 01M301      2015-2016       TECHNOLOGY, ARTS, AND SCIENCES STUDIO
# ...               ...                                         ...
# 84X703      2020-2021   BRONX PREPARATORY CHARTER SCHOOL (84X703)
# 84X704      2020-2021        KIPP ACADEMY CHARTER SCHOOL (84X704)
# 84X706      2020-2021      HARRIET TUBMAN CHARTER SCHOOL (84X706)
# 84X717      2020-2021               ICAHN CHARTER SCHOOL (84X717)
# 84X730      2020-2021  BRONX CHARTER SCHOOL FOR THE ARTS (84X730)
#
#             Students_in_HS_Admissions  Testers  Offers  Acceptance_Rate  \
# School_DBN
# 01M034                            8.0        8       3            37.50
# 01M140                           14.0       14       3            21.43
# 01M184                           39.0       39      19            48.72
# 01M188                            3.0        3       3           100.00
# 01M301                            6.0        6       3            50.00
# ...                               ...      ...     ...              ...
# 84X703                           19.0        8       3            37.50
# 84X704                           15.0        6       3            50.00
# 84X706                           64.0       15       3            20.00
# 84X717                           29.0        7       3            42.86
# 84X730                          100.0       13       3            23.08
#
#             Application_Rate
# School_DBN
# 01M034                100.00
# 01M140                100.00
# 01M184                100.00
# 01M188                100.00
# 01M301                100.00
# ...                      ...
# 84X703                 42.11
# 84X704                 40.00
# 84X706                 23.44
# 84X717                 24.14
# 84X730                 13.00
#
# [3620 rows x 7 columns]

# %%
a = shsat['Year'].astype(str)
clean_year = []

for x in a:
    list1 = x[7:9]
    clean_year.append(list1)
    
shsat['Year'] = clean_year
shsat

#admission rate
## acceptance rate to math grade..
## acceptance rate to attendance..

#district one has low count of students going in to take this test..
# Out:
#            Year                          Feeder_School_Name  \
# School_DBN
# 01M034       16              P.S. 034 FRANKLIN D. ROOSEVELT
# 01M140       16                      P.S. 140 NATHAN STRAUS
# 01M184       16                        P.S. 184M SHUANG WEN
# 01M188       16                  P.S. 188 THE ISLAND SCHOOL
# 01M301       16       TECHNOLOGY, ARTS, AND SCIENCES STUDIO
# ...         ...                                         ...
# 84X703       21   BRONX PREPARATORY CHARTER SCHOOL (84X703)
# 84X704       21        KIPP ACADEMY CHARTER SCHOOL (84X704)
# 84X706       21      HARRIET TUBMAN CHARTER SCHOOL (84X706)
# 84X717       21               ICAHN CHARTER SCHOOL (84X717)
# 84X730       21  BRONX CHARTER SCHOOL FOR THE ARTS (84X730)
#
#             Students_in_HS_Admissions  Testers  Offers  Acceptance_Rate  \
# School_DBN
# 01M034                            8.0        8       3            37.50
# 01M140                           14.0       14       3            21.43
# 01M184                           39.0       39      19            48.72
# 01M188                            3.0        3       3           100.00
# 01M301                            6.0        6       3            50.00
# ...                               ...      ...     ...              ...
# 84X703                           19.0        8       3            37.50
# 84X704                           15.0        6       3            50.00
# 84X706                           64.0       15       3            20.00
# 84X717                           29.0        7       3            42.86
# 84X730                          100.0       13       3            23.08
#
#             Application_Rate
# School_DBN
# 01M034                100.00
# 01M140                100.00
# 01M184                100.00
# 01M188                100.00
# 01M301                100.00
# ...                      ...
# 84X703                 42.11
# 84X704                 40.00
# 84X706                 23.44
# 84X717                 24.14
# 84X730                 13.00
#
# [3620 rows x 7 columns]

# %%
#att['Grade'] = att['Grade'].fillna(0).astype(int)

# %%
shsat = shsat.reset_index()

# %%
shsat.rename(columns = {'School_DBN': 'DBN'}, inplace = True)
shsat.set_index('DBN', inplace = True)

# %%
shsat = shsat[shsat.index.str.contains('02M') | shsat.index.str.contains('24Q')  | 
                shsat.index.str.contains('31R') | shsat.index.str.contains('20K')  | 
                shsat.index.str.contains('10X')]

# %%
shsat
# Out:
#        Year                                 Feeder_School_Name  \
# DBN
# 02M104   16                            J.H.S. 104 SIMON BARUCH
# 02M114   16                            EAST SIDE MIDDLE SCHOOL
# 02M126   16                         P.S. 126 JACOB AUGUST RIIS
# 02M131   16                                           M.S. 131
# 02M167   16                        J.H.S. 167 ROBERT F. WAGNER
# ...     ...                                                ...
# 31R063   21  MARSH AVENUE SCHOOL FOR EXPEDITIONARY LEARNING...
# 31R072   21                     I.S. 072 ROCCO LAURIE (31R072)
# 31R075   21                   I.S. 075 FRANK D. PAULO (31R075)
# 31R080   21            THE MICHAEL J. PETRIDES SCHOOL (31R080)
# 31R861   21  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP (31R861)
#
#         Students_in_HS_Admissions  Testers  Offers  Acceptance_Rate  \
# DBN
# 02M104                      195.0      195      50            25.64
# 02M114                       97.0       97      63            64.95
# 02M126                       76.0       76      29            38.16
# 02M131                       57.0       57      12            21.05
# 02M167                      283.0      283      78            27.56
# ...                           ...      ...     ...              ...
# 31R063                      146.0       51       3             5.88
# 31R072                      505.0      134      16            11.94
# 31R075                      448.0      161      41            25.47
# 31R080                       82.0       28       3            10.71
# 31R861                       88.0       21       3            14.29
#
#         Application_Rate
# DBN
# 02M104            100.00
# 02M114            100.00
# 02M126            100.00
# 02M131            100.00
# 02M167            100.00
# ...                  ...
# 31R063             34.93
# 31R072             26.53
# 31R075             35.94
# 31R080             34.15
# 31R861             23.86
#
# [562 rows x 7 columns]

# %%
shsat['Year'] = shsat['Year'].astype(int)

# %%
test= att.merge(shsat, how = 'left', on = ['DBN', 'Year']).dropna()

# %%
test
# Out:
#         Year  Attendance                        Feeder_School_Name  \
# DBN
# 02M104    16        94.3                   J.H.S. 104 SIMON BARUCH
# 02M104    17        94.8                   J.H.S. 104 SIMON BARUCH
# 02M104    18        95.3                   J.H.S. 104 SIMON BARUCH
# 02M104    19        95.0                   J.H.S. 104 SIMON BARUCH
# 02M114    16        96.8                   EAST SIDE MIDDLE SCHOOL
# ...      ...         ...                                       ...
# 31R075    19        93.7                   I.S. 075 FRANK D. PAULO
# 31R080    16        94.8            THE MICHAEL J. PETRIDES SCHOOL
# 31R080    17        94.3            THE MICHAEL J. PETRIDES SCHOOL
# 31R080    18        93.9            THE MICHAEL J. PETRIDES SCHOOL
# 31R861    18        93.7  STATEN ISLAND SCHOOL OF CIVIC LEADERSHIP
#
#         Students_in_HS_Admissions  Testers  Offers  Acceptance_Rate  \
# DBN
# 02M104                      195.0    195.0    50.0            25.64
# 02M104                      408.0    251.0    83.0            33.07
# 02M104                      386.0    260.0    53.0            20.38
# 02M104                      388.0    217.0    60.0            27.65
# 02M114                       97.0     97.0    63.0            64.95
# ...                           ...      ...     ...              ...
# 31R075                      462.0    143.0    38.0            26.57
# 31R080                       24.0     24.0     6.0            25.00
# 31R080                       91.0     24.0     3.0            12.50
# 31R080                       93.0     22.0     3.0            13.64
# 31R861                       96.0     34.0     3.0             8.82
#
#         Application_Rate
# DBN
# 02M104            100.00
# 02M104             61.52
# 02M104             67.36
# 02M104             55.93
# 02M114            100.00
# ...                  ...
# 31R075             30.95
# 31R080            100.00
# 31R080             26.37
# 31R080             23.66
# 31R861             35.42
#
# [3682 rows x 8 columns]

# %%
test.to_csv('attendace_corr_shsat')
